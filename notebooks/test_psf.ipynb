# %% [markdown]
# # PSF tests
# A notebook to handle PSFs
#
# ## Imports

# %%
from MER_PsfMosaic.PsfFactory import PsfFactory
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-7e06516586ef> in <module>
# ----> 1 from MER_PsfMosaic.PsfFactory import PsfFactory
#       2 import matplotlib
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 import matplotlib.pyplot as plt
#       5
#
# ModuleNotFoundError: No module named 'MER_PsfMosaic'

# %% [markdown]
# ## Load PSF

# %%
psf = PsfFactory.get_psf('VIS', '../../../data/PSFs/TILE40012/EUC_MER_GRID-PSF-VIS_EB04A7_20200228T090943.958368Z_00.00.fits')
plt.imshow(psf.get_data())
plt.show()
